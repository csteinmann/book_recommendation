# %%
import numpy as np
import pandas as pd
import os
import gzip
import json
import re
import pathlib

BASE_DIR = pathlib.Path().resolve()

# %% [markdown]
# Read the needed csv files

# %%
book_df = pd.read_csv(os.path.join(BASE_DIR, 'df_books.csv'))
user_df = pd.read_csv(os.path.join(BASE_DIR, 'df_users.csv'))

# %%
count_zero_rows = len(user_df[user_df['user_rating'] == 0])
print(count_zero_rows)
# Out:
# 551885

# %% [markdown]
# Check if any value in the relevant columns for building the recommender models is missing

# %%
user_df[['book_id', 'user_id', 'user_rating']].isnull().values.any()
# Out:
# False

# %% [markdown]
# Change dtypes in the book dataframe

# %%
book_df = book_df.astype({'publication_year': 'Int64', 'num_pages': 'Int64'})

# %% [markdown]
# Creating a dataframe for the recommender systems consisting of columns for book_id, user_id, and user_ratings <br>
# Renaming of the columns is necessary for the lenskit specification

# %%
user_counts = user_df['user_id'].value_counts()
users_with_enough_ratings = user_counts[user_counts >= 15].index
filtered_df = user_df[user_df['user_id'].isin(users_with_enough_ratings)]

# %%
model_df = filtered_df[['book_id', 'user_id', 'user_rating']]
model_df = model_df.rename(columns={'book_id': 'item', 'user_id': 'user', 'user_rating': 'rating'})

# %%
book_df = book_df[book_df['title_without_series'].notna()]

# %% [markdown]
# Import the lenskit modules

# %%
from lenskit.algorithms import Recommender, item_knn, user_knn, als
from lenskit import crossfold as xf
from lenskit import topn, util
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# Encode the user column to work properly in the fitting process

# %%
enc = OrdinalEncoder()
enc.fit(model_df[['user']])
model_df[['user']] = enc.transform(model_df[['user']])
model_df = model_df.astype({'user': 'Int64'})

# %% [markdown]
# Configurating the 3 different algorithms

# %%
nnbrs = 20
min_nbrs = 1
min_sim = 0.1
feedback = 'explicit'
center = True

algo_ii = item_knn.ItemItem(nnbrs=nnbrs, min_nbrs=min_nbrs, min_sim=min_sim, feedback=feedback, center=center)

# %%
nnbrs = 30
min_nbrs = 1
min_sim = 0.1
feedback = 'explicit'
center = True

algo_uu = user_knn.UserUser(nnbrs=nnbrs, min_nbrs=min_nbrs, min_sim=min_sim, feedback=feedback, center=center)

# %%
features = 50
iterations = 20
reg = 0.1
damping = 5

algo_als = als.BiasedMF(features=features, iterations=iterations, reg=reg, damping=damping)

# %% [markdown]
# Copying the algorithms and adapting them for later recommendation task

# %%
fit_algo_ii = Recommender.adapt(algo_ii)
fit_algo_uu = Recommender.adapt(algo_uu)
fit_algo_als = Recommender.adapt(algo_als)

# %% [markdown]
# Fitting the algorithms using 5 times crossvalidation

# %%
for i, tp in enumerate(xf.partition_users(model_df, 5, xf.SampleFrac(0.2))):
    train_split = tp.train.copy()
    
    #fit_algo_ii.fit(train_split)
    #print('Finished round {} of fitting the Item-Item model'.format(i+1))
    fit_algo_uu.fit(train_split)
    print("Finished round {} of fitting the User-User model".format(i+1))
    fit_algo_als.fit(train_split)
    print("Finished round {} of fitting the ALS model".format(i+1))
# Out:
# Finished round 1 of fitting the User-User model
# Finished round 1 of fitting the ALS model
# Finished round 2 of fitting the User-User model
# Finished round 2 of fitting the ALS model
# Finished round 3 of fitting the User-User model
# Finished round 3 of fitting the ALS model
# Finished round 4 of fitting the User-User model
# Finished round 4 of fitting the ALS model
# Finished round 5 of fitting the User-User model
# Finished round 5 of fitting the ALS model

# %%
from pandas import Series

# %% [markdown]
# Creating a new user which was not a part of the fitting process. Creating top-10 recommendation for this user with each algorithm

# %%
 user_ratings = {
     18490: 4, # Frankenstein
     29579: 4, # Foundation
     333867: 4, # The Stars My Destination
     95558: 3, # Solaris
     234225: 5, # Dune
     16690: 5, # The Moon is a Harsh Mistress
     77566: 5, # Hyperion
     7677: 5, # Jurassic Park
     5470: 4, # 1984
     5129: 3, # Brave New World
     4981: 4, # Slaughterhouse-Five
     2767052: 5, # The Hunger Games
     830: 4, # Snow Crash
     7613: 3, # Animal Farm
     227463: 4 # A Clockwork Orange
} 

#recs_ii = fit_algo_ii.recommend(user=-1, n=10, ratings=Series(user_ratings))
recs_uu = fit_algo_uu.recommend(user=-1, n=10, ratings=Series(user_ratings))
recs_als = fit_algo_als.recommend(user=-1, n=10, ratings=Series(user_ratings))

# %%
recs_ii
# Out:
#        item     score
# 0    727624  5.201815
# 1     19848  5.035149
# 2   1001558  4.776514
# 3  16068627  4.776502
# 4  10114864  4.701815
# 5    827715  4.146260
# 6   6760149  3.883634
# 7   1118509  3.590704
# 8   1505932  3.559064

# %%
recs_als
# Out:
#        item     score
# 0  33231678  5.280865
# 1  33020988  5.245990
# 2    576565  5.223198
# 3  26258444  5.212183
# 4  25521906  5.202399
# 5  24431330  5.196244
# 6    340381  5.193257
# 7  25819278  5.187523
# 8  28796537  5.169750
# 9  33118312  5.167935

# %%
book_df.loc[book_df['book_id']==33118312	]
# Out:
#          book_id title_without_series  \
# 315028  33118312              Refugee
#
#                                          book_description  publication_year  \
# 315028  JOSEF is a Jewish boy living in 1930s Nazi Ger...              2017
#
#          publisher  ratings_count  book_average_rating  \
# 315028  Scholastic           2172                 4.66
#
#                                                cover_page  \
# 315028  https://images.gr-assets.com/books/1487620933m...
#
#                                                  book_url  is_ebook  num_pages
# 315028  https://www.goodreads.com/book/show/33118312-r...      True        352

# %%
pd.set_option('display.max_colwidth', 100)
book_df.loc[book_df['title_without_series'].str.contains('A Clockwork Orange')].sort_values(by=['ratings_count'], ascending=False)
# Out:
#           book_id                      title_without_series  \
# 713043     227463                        A Clockwork Orange
# 1139156      8810                        A Clockwork Orange
# 1148977      8811                        A Clockwork Orange
# 906389   12399254                        A Clockwork Orange
# 304890      62373                        A Clockwork Orange
# 84852     5387987                        A Clockwork Orange
# 1170304   9598224                        A Clockwork Orange
# 1150833    200249                        A Clockwork Orange
# 229477       8812                        A Clockwork Orange
# 569632   19378389                        A Clockwork Orange
# 716552    6392169                        A Clockwork Orange
# 834701   12966982                        A Clockwork Orange
# 1234215   1003280                        A Clockwork Orange
# 633534     998045                        A Clockwork Orange
# 879717    7960340                        A Clockwork Orange
# 1298062   8532351                        A Clockwork Orange
# 1081934     22578                        A Clockwork Orange
# 589716   12025864                        A Clockwork Orange
# 953847   13707604                        A Clockwork Orange
# 761323     101194                        A Clockwork Orange
# 345676     753273                        A Clockwork Orange
# 1234214   1003285                        A Clockwork Orange
# 338728   13155986                        A Clockwork Orange
# 88879      937623                        A Clockwork Orange
# 220107     414948                        A Clockwork Orange
# 687266    7084555  A Clockwork Orange / Honey for the Bears
# 862061    1003287                        A Clockwork Orange
# 417145   16082193                        A Clockwork Orange
# 1265648  16372830                        A Clockwork Orange
# 1066621    673665                        A Clockwork Orange
# 336510   11292908                        A Clockwork Orange
# 71500    12419485                        A Clockwork Orange
# 529078     937625                        A Clockwork Orange
# 237574    1003290                        A Clockwork Orange
# 1292667  13620018                        A Clockwork Orange
# 969571   17937722                        A Clockwork Orange
# 1080966  17569719                        A Clockwork Orange
# 462019   15835509                        A Clockwork Orange
# 1150495   1138650                        A Clockwork Orange
#
#                                                                                             book_description  \
# 713043   A vicious fifteen-year-old "droog" is the central character of this 1963 classic, whose stark te...
# 1139156  Told by the central character, Alex, this brilliant, hilarious, and disturbing novel creates an ...
# 1148977  In Burgess's infamous nightmare vision of youth culture in revolt, 15-year-old Alex, a charismat...
# 906389   A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
# 304890   Fifteen-year-old Alex and his three friends start an evening's mayhem by hitting an old man, tea...
# 84852    Anthony Burgess's A Clockwork Orangeis the shocking seminal novel that spawned one of the most n...
# 1170304  "What we were after was lashings of ultraviolence."\nIn this nightmare vision of youth in revolt...
# 1150833  Der junge Alex prugelt, vergewaltigt, totet - bis man mit Hilfe moderner Technik einen wahren Ch...
# 229477   Adrift in the impersonal, iron-gray society of the superstate, the novel's main character, 15-ye...
# 569632   This is a fully restored edition of Anthony Burgess' original text of A Clockwork Orange, with a...
# 716552   Librarian note: an alternate cover for this edition can be found .\nTold by the central charact...
# 834701   A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
# 1234215  A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
# 633534   "Anthony Burgess reads chapters of his novel A Clockwork Orangewith hair-raising drive and energ...
# 879717   A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
# 1298062  The Norton Critical Edition ofA Clockwork Orangeis based on the first British edition and includ...
# 1081934  A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
# 589716   A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
# 953847   A Clockwork Orangeis as brilliant, transgressive, and influential as when it was published fifty...
# 761323   A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
# 345676   A brilliant reading from the novel by one of the wittiest commentators and literary figures of t...
# 1234214  A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
# 338728   The fully restored fiftieth anniversary edition\nForeword by Martin Amis\nFirst published by Wil...
# 88879    A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
# 220107   A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
# 687266                                                                                                   NaN
# 862061   A brilliant reading from the novel by one of the wittiest commentators and literary figures of t...
# 417145   A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
# 1265648  A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
# 1066621  A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
# 336510   Stanley Kubrick's futuristic juvenile delinquency movie A Clockwork Orange(1971) is an adaptatio...
# 71500    A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
# 529078   A vicious 15-year-old hoodlum is the central character of this modern classic, first published i...
# 237574   Anthony Burgess's modern classic of youthful violence and social redemption, reissued to include...
# 1292667  A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
# 969571   A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
# 1080966  A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
# 462019   An edition of ISBN10: 0140032193; ISBN13: 9780140032192.\nFifteen-year-old Alex and his three fr...
# 1150495  A vicious fifteen-year-old droog is the central character of this 1963 classic. In Anthony Burge...
#
#          publication_year                               publisher  \
# 713043               1995                   W. W. Norton  Company
# 1139156              2000                        Penguin Classics
# 1148977              1998                 Penguin Modern Classics
# 906389               2011                  W. W. Norton & Company
# 304890               1972                           Penguin Books
# 84852                2008                           Penguin Group
# 1170304              2011                                 Penguin
# 1150833              1997                       Heyne Taschenbuch
# 229477               1971                        Ballantine Books
# 569632               2013                           Penguin Books
# 1292667                     https://www.goodreads.com/book/show/13620018-a-clockwork-orange
# 969571                      https://www.goodreads.com/book/show/17937722-a-clockwork-orange
# 1080966                     https://www.goodreads.com/book/show/17569719-a-clockwork-orange
# 462019                      https://www.goodreads.com/book/show/15835509-a-clockwork-orange
# 1150495                      https://www.goodreads.com/book/show/1138650.A_Clockwork_Orange
#
#          is_ebook  num_pages
# 713043      False        212
# 1139156     False        141
# 1148977     False        160
# 906389       True       <NA>
# 304890      False        149
# 84852       False        141
# 1170304     False        141
# 1150833     False        224
# 229477      False        191
# 569632      False        306
# 716552      False        141
# 834701       True       <NA>
# 1234215     False        149
# 633534      False        219
# 879717      False        165
# 1298062     False        368
# 1081934     False          8
# 589716      False        158
# 953847      False        246
# 761323      False        196
# 345676      False        192
# 1234214     False        296
# 338728      False        352
# 88879       False        191
# 220107      False        187
# 687266      False        436
# 862061      False        185
# 417145      False          8
# 1265648     False        140
# 1066621     False        188
# 336510      False        200
# 71500        True        165
# 529078      False        192
# 237574      False        192
# 1292667     False       <NA>
# 969571      False       <NA>
# 1080966     False        185
# 462019      False        149
# 1150495     False       <NA>

# %% [markdown]
# Saving the recommendations to csv files

# %%
#recs_uu.to_csv('recs_uu.csv', encoding='utf-8')
recs_ii.to_csv('recs_ii.csv', encoding='utf-8')
#recs_als.to_csv('recs_als.csv', encoding='utf-8')

# %%
pd.set_option('display.max_colwidth', 2000)
book_df.loc[book_df['title_without_series'].str.contains('We, the Drowned')]
# Out:
#           book_id title_without_series  \
# 375584   12793962      We, the Drowned
# 399073    7988467      We, the Drowned
# 475556   10477987      We, the Drowned
# 1176715  13429545      We, the Drowned
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                book_description  \
# 375584                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          In 1848 a motley crew of Danish sailors sets sail from a small town of Marstal to fight the Germans. Not all of them return - and those who do will never be the same again. Among them is the daredevil Laurids Madsen, who promptly escapes again into the anonymity of the high seas. Spanning four generations, two world wars and a hundred years, We, The Drowned is an epic tale of adventure, ruthlessness and passion.
# 399073                                                                                                                       It is an epic drama of adventure, courage, ruthlessness and passion by one of Scandinavia's most acclaimed storytellers.\nIn 1848 a motley crew of Danish sailors sets sail from the small island town of Marstal to fight the Germans. Not all of them return - and those who do will never be the same. Among them is the daredevil Laurids Madsen, who promptly escapes again into the anonymity of the high seas.\nAs soon as he is old enough, his son Albert sets off in search of his missing father on a voyage that will take him to the furthest reaches of the globe and into the clutches of the most nefarious company. Bearing a mysterious shrunken head, and plagued by premonitions of bloodshed, he returns to a town increasingly run by women - among them a widow intent on liberating all men from the tyranny of the sea.\nFrom the barren rocks of Newfoundland to the lush plantations of Samoa, from the roughest bars in Tasmania, to the frozen coasts of northern Russia, We, The Drowned spans four generations, two world wars and a hundred years. Carsten Jensen conjures a wise, humorous, thrilling story of fathers and sons, of the women they love and leave behind, and of the sea's murderous promise. This is a novel destined to take its place among the greatest seafaring literature.
# 475556                                                                                                                       It is an epic drama of adventure, courage, ruthlessness and passion by one of Scandinavia's most acclaimed storytellers.\nIn 1848 a motley crew of Danish sailors sets sail from the small island town of Marstal to fight the Germans. Not all of them return - and those who do will never be the same. Among them is the daredevil Laurids Madsen, who promptly escapes again into the anonymity of the high seas.\nAs soon as he is old enough, his son Albert sets off in search of his missing father on a voyage that will take him to the furthest reaches of the globe and into the clutches of the most nefarious company. Bearing a mysterious shrunken head, and plagued by premonitions of bloodshed, he returns to a town increasingly run by women - among them a widow intent on liberating all men from the tyranny of the sea.\nFrom the barren rocks of Newfoundland to the lush plantations of Samoa, from the roughest bars in Tasmania, to the frozen coasts of northern Russia, We, The Drowned spans four generations, two world wars and a hundred years. Carsten Jensen conjures a wise, humorous, thrilling story of fathers and sons, of the women they love and leave behind, and of the sea's murderous promise. This is a novel destined to take its place among the greatest seafaring literature.
# 1176715  AN INTERNATIONAL BESTSELLER\nA THRILLING EPIC TALE OF THE SEA\n"We, the Drownedsets sail beyond the narrow channels of the seafaring genre and approaches Tolstoy in its evocation of war's confusion, its power to stun victors and vanquished alike . . . A gorgeous, unsparing novel." -- Washington Post\n"A generational saga, a swashbuckling sailor's tale, and the account of a small town coming into modernity--both Melville and Steinbeck might have been pleased to read it." -- New Republic\nHailed in Europe as an instant classic, We, the Drowned is the story of the port town of Marstal, Denmark, whose inhabitants sailed the world from the mid-nineteenth century to the end of the Second World War. The novel tells of ships wrecked and blown up in wars, of places of terror and violence that continue to lure each generation; there are cannibals here, shrunken heads, prophetic dreams, and miraculous survivals. The result is a brilliant seafaring novel, a gripping saga encompassing industrial growth, the years of expansion and exploration, the crucible of the first half of the twentieth century, and most of all, the sea.\nCalled "one of the most exciting authors in Nordic literature" by Henning Mankell, Carsten Jensen has worked as a literary critic and a journalist, reporting from China, Cambodia, Latin America, the Pacific Islands, and Afghanistan. He lives in Copenhagen and Marstal.
#
#          publication_year                  publisher  ratings_count  \
# 375584               2011                    Vintage            203
# 399073               2011  Houghton Mifflin Harcourt           4248
# 475556               <NA>                        NaN            264
# 1176715              2012              Mariner Books            151
#
#          book_average_rating  \
# 375584                  4.22
# 399073                  4.22
# 475556                  4.22
# 1176715                 4.22
#
#                                                                                        cover_page  \
# 375584                                https://images.gr-assets.com/books/1438026498m/12793962.jpg
# 399073                                 https://images.gr-assets.com/books/1303518744m/7988467.jpg
# 475556   https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png
# 1176715                               https://images.gr-assets.com/books/1344671069m/13429545.jpg
#
#                                                             book_url  \
# 375584   https://www.goodreads.com/book/show/12793962-we-the-drowned
# 399073    https://www.goodreads.com/book/show/7988467-we-the-drowned
# 475556   https://www.goodreads.com/book/show/10477987-we-the-drowned
# 1176715  https://www.goodreads.com/book/show/13429545-we-the-drowned
#
#          is_ebook  num_pages
# 375584      False        693
# 399073      False        688
# 475556       True        693
# 1176715     False        688

# %%
book_df.loc[book_df['book_id']==28600911]
# Out:
#          book_id                               title_without_series  \
# 273607  28600911  Curse of Strahd (Dungeons & Dragons, 5th Edition)
#
#                                          book_description  publication_year  \
# 273607  Unravel the mysteries of Ravenloft(r) in this ...              2016
#
#                    publisher  ratings_count  book_average_rating  \
# 273607  Wizards of the Coast            279                  4.5
#
#                                                cover_page  \
# 273607  https://images.gr-assets.com/books/1456090369m...
#
#                                                  book_url  is_ebook  num_pages
# 273607  https://www.goodreads.com/book/show/28600911-c...     False        256
